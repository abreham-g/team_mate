# %%
import pandas as pd

# %%
df = pd.read_csv('/home/abreham/Documents/GenAI/GenAI/team-mate/all_nov_jobs.csv')
df
# Out:
#        Unnamed: 0.2                                          title  \
# 0                 0                              Software Engineer
# 1                 1  Software Test Engineer / SDET - (Remote - US)
# 2                 2                              Software Engineer
# 3                 3             AUTOSAR Software Engineer - REMOTE
# 4                 4             AUTOSAR Software Engineer - REMOTE
# ...             ...                                            ...
# 16833         17304                Software Engineer II - C/C++/OS
# 16834         17305                Software Engineer II - C/C++/OS
# 16835         17306                Software Engineer II - C/C++/OS
# 16836         17307                Software Engineer II - C/C++/OS
# 16837         17308                Software Engineer II - C/C++/OS
#
#             company                                company_link  \
# 0               NaN   https://www.linkedin.com/company/9384440/
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.2', 'title', 'company', 'company_link', 'place', 'date',
#        'apply_link', 'post_link', 'seniority_level', 'employmnet_type',
#        'description', 'job_title_id', 'job_desc_id', 'Unnamed: 0',
#        'Unnamed: 0.1', 'Unnamed: 0.1.1'],
#       dtype='object')

# %%
# Assuming your DataFrame is named 'df'
df = df.drop(columns=[col for col in df.columns if 'Unnamed' in col])
df
# Out:
#                                                title       company  \
# 0                                  Software Engineer           NaN
# 1      Software Test Engineer / SDET - (Remote - US)     Mediavine
# 2                                  Software Engineer  Bayes Invest
# 3                 AUTOSAR Software Engineer - REMOTE      Actalent
# 4                 AUTOSAR Software Engineer - REMOTE      Actalent
# ...                                              ...           ...
# 16833                Software Engineer II - C/C++/OS     Microsoft
# 16834                Software Engineer II - C/C++/OS     Microsoft
# 16835                Software Engineer II - C/C++/OS     Microsoft
# 16836                Software Engineer II - C/C++/OS     Microsoft
# 16837                Software Engineer II - C/C++/OS     Microsoft
#
#                                      company_link  \
# 0       https://www.linkedin.com/company/9384440/
# 1      https://www.linkedin.com/company/71904349/
# ...

# %%
filter_df = df[:5]
filter_df
# Out:
#                                            title       company  \
# 0                              Software Engineer           NaN
# 1  Software Test Engineer / SDET - (Remote - US)     Mediavine
# 2                              Software Engineer  Bayes Invest
# 3             AUTOSAR Software Engineer - REMOTE      Actalent
# 4             AUTOSAR Software Engineer - REMOTE      Actalent
#
#                                  company_link               place        date  \
# 0   https://www.linkedin.com/company/9384440/   Austin, TX Remote  2022-11-06
# 1  https://www.linkedin.com/company/71904349/  Phoenix, AZ Remote  2022-11-06
# 2  https://www.linkedin.com/company/71904349/  Detroit, MI Remote  2022-11-06
# 3  https://www.linkedin.com/company/71904349/  Bothell, WA Remote  2022-11-06
# 4  https://www.linkedin.com/company/71904349/  Raleigh, NC Remote  2022-11-06
#
#                                           apply_link  \
# 0                                                NaN
# ...

# %%
df.dtypes
# Out:
# title              object
# company            object
# company_link       object
# place              object
# date               object
# apply_link         object
# post_link          object
# seniority_level    object
# employmnet_type    object
# description        object
# job_title_id        int64
# job_desc_id         int64
# dtype: object
